# %% [markdown]
# <a href="https://colab.research.google.com/github/lisabroadhead/data_science_machine-learning/blob/main/olympian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Find Average Height Per Individual Olympian Per Year Exercise (Core)
# - Lisa Broadhead
# - June 4, 2022

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Load this dataset and explore it! Answer the following questions:

# %%
file = '/content/drive/MyDrive/Colab Notebooks/coding_dojo/files/athleteEventsNoPersonal.csv'
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    ID   Age  Height         Team  NOC        Games  Year  Season         City  \
# 0   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 1   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 2   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 3   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 4   5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
#
#            Sport                               Event Medal
# 0  Speed Skating    Speed Skating Women's 500 metres   NaN
# 1  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 2  Speed Skating    Speed Skating Women's 500 metres   NaN
# 3  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 4  Speed Skating    Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ### A. How many rows?

# %%
df.shape
# Out:
# (40616, 12)

# %%
print(f"Numbes of rows is: {df.shape[0]}")
# Out:
# Numbes of rows is: 40616

# %% [markdown]
# ### B. How many columns?

# %%
print(f"Numbes of columns is: {df.shape[1]}")
# Out:
# Numbes of columns is: 12

# %% [markdown]
# ### C. Which columns have missing values? (Why do think there are there so many null values in the Medals column?)

# %%
df.isna().sum()
# Out:
# ID            0
# Age        1473
# Height     9001
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     34699
# dtype: int64

# %%
# Age: Looks like its a value that didn't get inputed. There's no corrilation between year, country, or location
age = df['Age'].isnull()
df[age].sort_values('Height')
# Out:
#            ID  Age  Height            Team  NOC        Games  Year  Season  \
# 26983   90304  NaN   150.0          Turkey  TUR  1976 Summer  1976  Summer
# 29846   99239  NaN   152.0           Nepal  NEP  1988 Summer  1988  Summer
# 552      2105  NaN   153.0            Oman  OMA  1984 Summer  1984  Summer
# 8227    28165  NaN   156.0          Guinea  GUI  1988 Summer  1988  Summer
# 8226    28165  NaN   156.0          Guinea  GUI  1980 Summer  1980  Summer
# ...       ...  ...     ...             ...  ...          ...   ...     ...
# 40437  135070  NaN     NaN  Czechoslovakia  TCH  1920 Summer  1920  Summer
# 40442  135081  NaN     NaN          Greece  GRE  1906 Summer  1906  Summer
# 40443  135081  NaN     NaN          Greece  GRE  1906 Summer  1906  Summer
# 40450  135107  NaN     NaN       Marie-Tim  GRE  1952 Summer  1952  Summer
# 40556  135435  NaN     NaN           Chile  CHI  1928 Summer  1928  Summer
#
# ...

# %%
# Height: Looking at the data is looks like the height just got missed. Somehow it didn't get put in. No certain country of year missed the data
height = df['Height'].isnull()
df[height][100:125].sort_values('Year')
# Out:
#        ID   Age  Height                                            Team  NOC  \
# 418  1538  20.0     NaN  Union des Socits Franais de Sports Athletiques  FRA
# 478  1706  20.0     NaN                                          Russia  RUS
# 439  1605  18.0     NaN                                       Lithuania  LTU
# 417  1536  50.0     NaN                                   United States  USA
# 444  1617  23.0     NaN                                          Sweden  SWE
# 442  1613  33.0     NaN                                         Finland  FIN
# 416  1532  29.0     NaN                                   Great Britain  GBR
# 431  1572  23.0     NaN                                           Japan  JPN
# 430  1572  23.0     NaN                                           Japan  JPN
# 429  1572  23.0     NaN                                           Japan  JPN
# 432  1572  23.0     NaN                                           Japan  JPN
# ...

# %%
# Medal - well this one makes sense. Nit everyone who goes gets a medal. so if you didn't get a medal the slot if left empty
medal = df['Medal'].unique
df['Medal'].unique()
# Out:
# array([nan, 'Silver', 'Gold', 'Bronze'], dtype=object)

# %% [markdown]
# ### D. How many entries correspond to the city of London?

# %%
df.head()
# Out:
#    ID   Age  Height         Team  NOC        Games  Year  Season         City  \
# 0   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 1   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 2   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 3   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 4   5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
#
#            Sport                               Event Medal
# 0  Speed Skating    Speed Skating Women's 500 metres   NaN
# 1  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 2  Speed Skating    Speed Skating Women's 500 metres   NaN
# 3  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 4  Speed Skating    Speed Skating Women's 500 metres   NaN

# %%
london = df['City'] == "London"
print(f"{len(df[london])} : Total entries that correspond to London")
# Out:
# 3370 : Total entries that correspond to London

# %% [markdown]
# ### E. What age is the youngest athlete in our sample data?  Hint: use min()

# %%
print(f"Youngest Athlete: {df['Age'].min()}")
# Out:
# Youngest Athlete: 11.0

# %% [markdown]
# ## 2. Create filters to find out:

# %% [markdown]
# ### A. How many athletes who participated in the Sport "Tug-Of-War" were from Team "Sweden" in our sample dataset?

# %%
df.head()
# Out:
#    ID   Age  Height         Team  NOC        Games  Year  Season         City  \
# 0   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 1   5  21.0   185.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 2   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 3   5  25.0   185.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 4   5  27.0   185.0  Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
#
#            Sport                               Event Medal
# 0  Speed Skating    Speed Skating Women's 500 metres   NaN
# 1  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 2  Speed Skating    Speed Skating Women's 500 metres   NaN
# 3  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 4  Speed Skating    Speed Skating Women's 500 metres   NaN

# %%
tug = df['Sport'] == "Tug-Of-War"
sweden = df['Team'] == "Sweden"

print(f"{len(df[tug & sweden])} : Were Swedish Tug-a-War athletes")
# Out:
# 6 : Were Swedish Tug-a-War athletes

# %% [markdown]
# ### B. How many Gold medals were awarded to athletes who were over 40 years old?

# %%
gold = df['Medal'] == 'Gold'
age = df['Age'] == 40

print(f"{len(df[gold & age])} : Athletes over 40 who won gold")
# Out:
# 10 : Athletes over 40 who won gold

# %% [markdown]
# ## 3. Determine the average height if:

# %% [markdown]
# ### A. All rows are included.

# %%
df.isna().sum()
# Out:
# ID            0
# Age        1473
# Height     9001
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     34699
# dtype: int64

# %%
# First where values are nan they now equal the mean - that way calucalations can be ran without skewing the data
df_height = df['Height'] > 0
df[df_height].info()
# avg
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31615 entries, 0 to 40615
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      31615 non-null  int64
#  1   Age     31474 non-null  float64
#  2   Height  31615 non-null  float64
#  3   Team    31615 non-null  object
#  4   NOC     31615 non-null  object
#  5   Games   31615 non-null  object
#  6   Year    31615 non-null  int64
#  7   Season  31615 non-null  object
#  8   City    31615 non-null  object
#  9   Sport   31615 non-null  object
#  10  Event   31615 non-null  object
#  11  Medal   4629 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.1+ MB

# %%
df[df_height].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ID        68348.855765
# Age          25.111870
# Height      175.381117
# Year       1989.112067
# dtype: float64

# %%
df['Height'].fillna(175.38, inplace = True)

# %%
df.head(50)
# Out:
#      ID   Age  Height           Team  NOC        Games  Year  Season  \
# 0     5  21.0  185.00    Netherlands  NED  1988 Winter  1988  Winter
# 1     5  21.0  185.00    Netherlands  NED  1988 Winter  1988  Winter
# 2     5  25.0  185.00    Netherlands  NED  1992 Winter  1992  Winter
# 3     5  25.0  185.00    Netherlands  NED  1992 Winter  1992  Winter
# 4     5  27.0  185.00    Netherlands  NED  1994 Winter  1994  Winter
# 5     5  27.0  185.00    Netherlands  NED  1994 Winter  1994  Winter
# 6     6  31.0  188.00  United States  USA  1992 Winter  1992  Winter
# 7     6  31.0  188.00  United States  USA  1992 Winter  1992  Winter
# 8     6  31.0  188.00  United States  USA  1992 Winter  1992  Winter
# 9     6  31.0  188.00  United States  USA  1992 Winter  1992  Winter
# 10    6  33.0  188.00  United States  USA  1994 Winter  1994  Winter
# 11    6  33.0  188.00  United States  USA  1994 Winter  1994  Winter
# 12    6  33.0  188.00  United States  USA  1994 Winter  1994  Winter
# ...

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ID        68140.888738
# Age          25.619498
# Height      175.380869
# Year       1978.653240
# dtype: float64

# %% [markdown]
# ### B. All rows are included but grouped by Event.

# %%
df.groupby(['Event'])['Height'].mean()
# Out:
# Event
# Alpine Skiing Men's Combined                      177.744225
# Alpine Skiing Men's Downhill                      177.421789
# Alpine Skiing Men's Giant Slalom                  176.334468
# Alpine Skiing Men's Slalom                        176.161266
# Alpine Skiing Men's Super G                       179.193137
#                                                      ...
# Wrestling Women's Flyweight, Freestyle            158.100000
# Wrestling Women's Heavyweight, Freestyle          173.444444
# Wrestling Women's Light-Heavyweight, Freestyle    170.000000
# Wrestling Women's Lightweight, Freestyle          162.666667
# Wrestling Women's Middleweight, Freestyle         164.533333
# Name: Height, Length: 726, dtype: float64

# %% [markdown]
# ### C. Bonus get the average height of all  the athletes, but don't include any athlete more than once.
#
# Hint 1: We learned how to drop duplicates if EVERY column was identical
#
# Hint 2: Drop a row any time just the ID is repeated. Use a subset of your data as an argument in the drop_duplicates function.

# %%
# Drops where everything is duplicate 
df.duplicated().sum()
# Out:
# 207

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# drop where IDs are duplicate
df = df.drop_duplicates(subset="ID")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20336 entries, 0 to 40614
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      20336 non-null  int64
#  1   Age     19388 non-null  float64
#  2   Height  20336 non-null  float64
#  3   Team    20336 non-null  object
#  4   NOC     20336 non-null  object
#  5   Games   20336 non-null  object
#  6   Year    20336 non-null  int64
#  7   Season  20336 non-null  object
#  8   City    20336 non-null  object
#  9   Sport   20336 non-null  object
#  10  Event   20336 non-null  object
#  11  Medal   2850 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 2.0+ MB

# %%
df['Height'].mean()
# Out:
# 176.08553009439487
