# %% [markdown]
# <a href="https://colab.research.google.com/github/lisabroadhead/machine-learning/blob/main/may_24_lesson_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Notbook tips
1. H! with the assigment title
2. Your name
3. date (when you finished)

EXAMPLE:

# %% [markdown]
# # Numpy Bakery
# >  Lisa Broadhead <br/>
# >  5.25.2022

# %% [markdown]
# # Write mark down cells to comment what you're seeing / doing / observations

# %%
# Stay organized and keep thing clean

# %% [markdown]
# # Belt Exam
# - Belt Exam Fri-Sum June 6/10 and have is submitted by Sunday 06/12/22 by 11:59PST
# - once you get the code you have 24 hours
# - Complete week 3 assigments before you do the exam
# - 1 retake if you don't pass

# %% [markdown]
# Differnet file type
# - .csv - pd.read_csv
# - .xsls - pd.read_excel

# %% [markdown]
# # LESSON STARTS HERRE

# %%
import pandas as pd

# %%
# df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/coding_dojo/files/RailsToTrails_National Count Data_week.xlsx')
file_name = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTD4EZkLl5Fxj3IqoDfQyhCn3Qw3EAx0NWXTz6fK82fXXotHqMnp946t62C0k7fyMCbyv0co0KsYlQH/pub?gid=1317515577&single=true&output=csv'
df = pd.read_csv(file_name)
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTD4EZkLl5Fxj3IqoDfQyhCn3Qw3EAx0NWXTz6fK82fXXotHqMnp946t62C0k7fyMCbyv0co0KsYlQH/pub?gid=1317515577&single=true&output=csv', header=None)
# df.head(5)
# see if you can rename
df.rename(columns=1,"one")
# Out:
#   File "<ipython-input-17-9741c8df455e>", line 4
#     df.rename(columns=1,"one")
#                        ^
# SyntaxError: positional argument follows keyword argument

# %%
df = pd.read_csv(file_name,header=2)
df.head(9)
# Out:
#    DRC01    5.92  Regular  0.019278216            Soft Drinks   48.2692  \
# 0  FDN15  17.500  Low Fat     0.016760                   Meat  141.6180
# 1  FDX07  19.200  Regular     0.000000  Fruits and Vegetables  182.0950
# 2  NCD19   8.930  Low Fat     0.000000              Household   53.8614
# 3  FDP36  10.395  Regular     0.000000           Baking Goods   51.4008
# 4  FDO10  13.650  Regular     0.012741            Snack Foods   57.6588
# 5  FDP10     NaN  Low Fat     0.127470            Snack Foods  107.7622
# 6  FDH17  16.200  Regular     0.016687           Frozen Foods   96.9726
# 7  FDU28  19.200  Regular     0.094450           Frozen Foods  187.8214
# 8  FDY07  11.800  Low Fat     0.000000  Fruits and Vegetables   45.5402
#
#    OUT018  2009  Medium  Tier 3  Supermarket Type2   443.4228
# 0  OUT049  1999  Medium  Tier 1  Supermarket Type1  2097.2700
# 1  OUT010  1998     NaN  Tier 3      Grocery Store   732.3800
# ...

# %%
# bottom 11 row
df.tail(11)
# Out:
#       DRC01    5.92  Regular  0.019278216         Soft Drinks   48.2692  \
# 8510  FDR26  20.700  Low Fat     0.042801               Dairy  178.3028
# 8511  FDH31  12.000  Regular     0.020407                Meat   99.9042
# 8512  FDA01  15.000  Regular     0.054489              Canned   57.5904
# 8513  FDH24  20.700  Low Fat     0.021518        Baking Goods  157.5288
# 8514  NCJ19  18.600  Low Fat     0.118661              Others   58.7588
# 8515  FDF53  20.750      reg     0.083607        Frozen Foods  178.8318
# 8516  FDF22   6.865  Low Fat     0.056783         Snack Foods  214.5218
# 8517  FDS36   8.380  Regular     0.046982        Baking Goods  108.1570
# 8518  NCJ29  10.600  Low Fat     0.035186  Health and Hygiene   85.1224
# 8519  FDN46   7.210  Regular     0.145221         Snack Foods  103.1332
# 8520  DRG01  14.800  Low Fat     0.044878         Soft Drinks   75.4670
#
#       OUT018  2009  Medium  Tier 3  Supermarket Type2   443.4228
# ...

# %%
# 5 random rows, defualt is 1
df.sample(5)
# Out:
#       DRC01   5.92  Regular  0.019278216            Soft Drinks   48.2692  \
# 3214  DRI37  15.85  Low Fat     0.180097            Soft Drinks   57.3904
# 6174  FDZ07  15.10      reg     0.094037  Fruits and Vegetables   62.3194
# 2004  NCL17   7.39  Low Fat     0.068163     Health and Hygiene  140.4812
# 2468  FDD26   8.71  Regular     0.120773                 Canned  186.5924
# 6566  FDJ48  11.30  Low Fat     0.056388           Baking Goods  245.4118
#
#       OUT018  2009  Medium  Tier 3  Supermarket Type2   443.4228
# 3214  OUT010  1998     NaN  Tier 3      Grocery Store   117.1808
# 6174  OUT049  1999  Medium  Tier 1  Supermarket Type1   495.3552
# 2004  OUT017  2007     NaN  Tier 2  Supermarket Type1  2422.1804
# 2468  OUT010  1998     NaN  Tier 3      Grocery Store   555.2772
# 6566  OUT013  1987    High  Tier 3  Supermarket Type1  6669.3186

# %% [markdown]
# ## Checking data type2
# - df.info()
# - df.dtypes()
# - df['name'].dtypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8521 entries, 0 to 8520
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DRC01              8521 non-null   object
#  1   5.92               7058 non-null   float64
#  2   Regular            8521 non-null   object
#  3   0.019278216        8521 non-null   float64
#  4   Soft Drinks        8521 non-null   object
#  5   48.2692            8521 non-null   float64
#  6   OUT018             8521 non-null   object
#  7   2009               8521 non-null   int64
#  8   Medium             6111 non-null   object
#  9   Tier 3             8521 non-null   object
#  10  Supermarket Type2  8521 non-null   object
#  11  443.4228           8521 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.0+ KB

# %%
df.dtypes
saved_dtypes = df.dtypes

# %%
# filter out everything but the objects
saved_dtypes[saved_dtypes == 'object']
# Out:
# DRC01                object
# Regular              object
# Soft Drinks          object
# OUT018               object
# Medium               object
# Tier 3               object
# Supermarket Type2    object
# dtype: object

# %%
# 
save_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8521 entries, 0 to 8520
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DRC01              8521 non-null   object
#  1   5.92               7058 non-null   float64
#  2   Regular            8521 non-null   object
#  3   0.019278216        8521 non-null   float64
#  4   Soft Drinks        8521 non-null   object
#  5   48.2692            8521 non-null   float64
#  6   OUT018             8521 non-null   object
#  7   2009               8521 non-null   int64
#  8   Medium             6111 non-null   object
#  9   Tier 3             8521 non-null   object
#  10  Supermarket Type2  8521 non-null   object
#  11  443.4228           8521 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.0+ KB

# %%
# just call it you get nothing, so it works differertnly
save_info

# %%
## dtypes for col 1
df['Regular']
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Regular
#          ...
# 8516    Low Fat
# 8517    Regular
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# Name: Regular, Length: 8521, dtype: object

# %%
df.shape
# Out:
# (8521, 12)

# %%
len(df)
# Out:
# 8521

# %%
len(df.columns)
# Out:
# 12

# %% [markdown]
# # Slicing
# - to select on column as a df['name']
# - to select one column

# %%
df.head()
# Out:
#    DRC01    5.92  Regular  0.019278216            Soft Drinks   48.2692  \
# 0  FDN15  17.500  Low Fat     0.016760                   Meat  141.6180
# 1  FDX07  19.200  Regular     0.000000  Fruits and Vegetables  182.0950
# 2  NCD19   8.930  Low Fat     0.000000              Household   53.8614
# 3  FDP36  10.395  Regular     0.000000           Baking Goods   51.4008
# 4  FDO10  13.650  Regular     0.012741            Snack Foods   57.6588
#
#    OUT018  2009  Medium  Tier 3  Supermarket Type2   443.4228
# 0  OUT049  1999  Medium  Tier 1  Supermarket Type1  2097.2700
# 1  OUT010  1998     NaN  Tier 3      Grocery Store   732.3800
# 2  OUT013  1987    High  Tier 3  Supermarket Type1   994.7052
# 3  OUT018  2009  Medium  Tier 3  Supermarket Type2   556.6088
# 4  OUT013  1987    High  Tier 3  Supermarket Type1   343.5528

# %%
df[['Regular', '5.92']]
# Out:
#       Regular    5.92
# 0     Low Fat  17.500
# 1     Regular  19.200
# 2     Low Fat   8.930
# 3     Regular  10.395
# 4     Regular  13.650
# ...       ...     ...
# 8516  Low Fat   6.865
# 8517  Regular   8.380
# 8518  Low Fat  10.600
# 8519  Regular   7.210
# 8520  Low Fat  14.800
#
# [8521 rows x 2 columns]

# %% [markdown]
# # Index

# %%
file_url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vSBBVejdY87e_8cMG9xUEu2Q2DiQC1rHBgmq9ecR8kduFcdsae_Z1B12303buUISaPhHWopT9-Howzi/pub?output=csv#"
df = pd.read_csv(file_url)

# %%
display(df.head())
df.index
# Out:
#    EmployeeID    Name  Height  Age State            Role
# 0           1     Tom      68   33    CA  Senior Advisor
# 1           2   Jerry      72   27    NY  Junior Advisor
# 2           3     Ann      69   42    MD    Senior Agent
# 3           4  Hubert      68   35    WA    Junior Agent
# 4           5  Monica      63   64    TX    Senior Agent
# RangeIndex(start=0, stop=11, step=1)

# %%
# setting the index
df = pd.read_csv(file_url, index_col=0)
display(df.head())
# Out:
#               Name  Height  Age State            Role
# EmployeeID
# 1              Tom      68   33    CA  Senior Advisor
# 2            Jerry      72   27    NY  Junior Advisor
# 3              Ann      69   42    MD    Senior Agent
# 4           Hubert      68   35    WA    Junior Agent
# 5           Monica      63   64    TX    Senior Agent

# %%
# Set index
df1 = pd.read_csv(file_url)
df1
# Out:
#     EmployeeID    Name  Height  Age State               Role
# 0            1     Tom      68   33    CA     Senior Advisor
# 1            2   Jerry      72   27    NY     Junior Advisor
# 2            3     Ann      69   42    MD       Senior Agent
# 3            4  Hubert      68   35    WA       Junior Agent
# 4            5  Monica      63   64    TX       Senior Agent
# 5            6    Suzy      65   15    MA       Juior Intern
# 6            7    Greg      70   45    CA  Senior Accountant
# 7            8     Bob      71   52    NY       Senior Agent
# 8            9    Nora      66   27    MD    PR Rep - Junior
# 9           10   Vadim      72   38    TX    PR Rep - Senior
# 10          11    John      74   24    RI      Senior Intern

# %%
df1.set_index('EmployeeID')
df1
# Out:
#     EmployeeID    Name  Height  Age State               Role
# 0            1     Tom      68   33    CA     Senior Advisor
# 1            2   Jerry      72   27    NY     Junior Advisor
# 2            3     Ann      69   42    MD       Senior Agent
# 3            4  Hubert      68   35    WA       Junior Agent
# 4            5  Monica      63   64    TX       Senior Agent
# 5            6    Suzy      65   15    MA       Juior Intern
# 6            7    Greg      70   45    CA  Senior Accountant
# 7            8     Bob      71   52    NY       Senior Agent
# 8            9    Nora      66   27    MD    PR Rep - Junior
# 9           10   Vadim      72   38    TX    PR Rep - Senior
# 10          11    John      74   24    RI      Senior Intern

# %%
# inpalce=tue

# %%
DF2 = pd.read_csv(file_url)
DF2
# Out:
#     EmployeeID    Name  Height  Age State               Role
# 0            1     Tom      68   33    CA     Senior Advisor
# 1            2   Jerry      72   27    NY     Junior Advisor
# 2            3     Ann      69   42    MD       Senior Agent
# 3            4  Hubert      68   35    WA       Junior Agent
# 4            5  Monica      63   64    TX       Senior Agent
# 5            6    Suzy      65   15    MA       Juior Intern
# 6            7    Greg      70   45    CA  Senior Accountant
# 7            8     Bob      71   52    NY       Senior Agent
# 8            9    Nora      66   27    MD    PR Rep - Junior
# 9           10   Vadim      72   38    TX    PR Rep - Senior
# 10          11    John      74   24    RI      Senior Intern

# %%
DF2.set_index("EmployeeID", inplace=True)
DF2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-61f7bff0672c> in <module>()
# ----> 1 DF2.set_index("EmployeeID", inplace=True)
#       2 DF2
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['EmployeeID'] are in the columns"

# %%
DF2
# Out:
#               Name  Height  Age State               Role
# EmployeeID
# 1              Tom      68   33    CA     Senior Advisor
# 2            Jerry      72   27    NY     Junior Advisor
# 3              Ann      69   42    MD       Senior Agent
# 4           Hubert      68   35    WA       Junior Agent
# 5           Monica      63   64    TX       Senior Agent
# 6             Suzy      65   15    MA       Juior Intern
# 7             Greg      70   45    CA  Senior Accountant
# 8              Bob      71   52    NY       Senior Agent
# 9             Nora      66   27    MD    PR Rep - Junior
# 10           Vadim      72   38    TX    PR Rep - Senior
# 11            John      74   24    RI      Senior Intern

# %%
df3 = pd.read_csv(file_url)
df3.head()
# Out:
#    EmployeeID    Name  Height  Age State            Role
# 0           1     Tom      68   33    CA  Senior Advisor
# 1           2   Jerry      72   27    NY  Junior Advisor
# 2           3     Ann      69   42    MD    Senior Agent
# 3           4  Hubert      68   35    WA    Junior Agent
# 4           5  Monica      63   64    TX    Senior Agent

# %%
df3 = df3.set_index('EmployeeID')

# %%
df3.head()
# Out:
#               Name  Height  Age State            Role
# EmployeeID
# 1              Tom      68   33    CA  Senior Advisor
# 2            Jerry      72   27    NY  Junior Advisor
# 3              Ann      69   42    MD    Senior Agent
# 4           Hubert      68   35    WA    Junior Agent
# 5           Monica      63   64    TX    Senior Agent

# %%
# NOT TOGETHER!!!
# they'll override eachother!
df = pd.read_csv(file_url)
display(df.head(2))

df = df.set_index('EmployeeID', inplace=True)
df
# Out:
#    EmployeeID   Name  Height  Age State            Role
# 0           1    Tom      68   33    CA  Senior Advisor
# 1           2  Jerry      72   27    NY  Junior Advisor

# %%
type(df)
# Out:
# NoneType

# %%
df

# %% [markdown]
# # Slicing Pandas Locators:
# - df.loc[]
# - df.iloc[] - only takes integers
#
# - row: observation
# - col: feature of variable

# %%
df = pd.read_csv(file_url, index_col=0)
df.head()
# Out:
#               Name  Height  Age State            Role
# EmployeeID
# 1              Tom      68   33    CA  Senior Advisor
# 2            Jerry      72   27    NY  Junior Advisor
# 3              Ann      69   42    MD    Senior Agent
# 4           Hubert      68   35    WA    Junior Agent
# 5           Monica      63   64    TX    Senior Agent

# %%
# df.iloc[7,:] - below is the shortcut
df.iloc[7]
# Out:
# Name               Bob
# Height              71
# Age                 52
# State               NY
# Role      Senior Agent
# Name: 8, dtype: object

# %%
df.head(8)
# Out:
#               Name  Height  Age State               Role
# EmployeeID
# 1              Tom      68   33    CA     Senior Advisor
# 2            Jerry      72   27    NY     Junior Advisor
# 3              Ann      69   42    MD       Senior Agent
# 4           Hubert      68   35    WA       Junior Agent
# 5           Monica      63   64    TX       Senior Agent
# 6             Suzy      65   15    MA       Juior Intern
# 7             Greg      70   45    CA  Senior Accountant
# 8              Bob      71   52    NY       Senior Agent

# %%
df.iloc[7:10]
# Out:
#              Name  Height  Age State             Role
# EmployeeID
# 8             Bob      71   52    NY     Senior Agent
# 9            Nora      66   27    MD  PR Rep - Junior
# 10          Vadim      72   38    TX  PR Rep - Senior

# %%
df.iloc[7,1]
# Out:
# 71

# %% [markdown]
# - , to get a value in a cell and : is returning a range

# %%
df.iloc[7,1:5]
# Out:
# Height              71
# Age                 52
# State               NY
# Role      Senior Agent
# Name: 8, dtype: object

# %%
# last row last column
df.iloc[-1,-1]
# Out:
# 'Senior Intern'

# %% [markdown]
# ### Genral locator
# - takes in strings or integers

# %%
df = pd.read_csv(file_url,index_col=1)
df.head(5)
# Out:
#         EmployeeID  Height  Age State            Role
# Name
# Tom              1      68   33    CA  Senior Advisor
# Jerry            2      72   27    NY  Junior Advisor
# Ann              3      69   42    MD    Senior Agent
# Hubert           4      68   35    WA    Junior Agent
# Monica           5      63   64    TX    Senior Agent

# %%
df.loc['Jerry', 'Height']
# Out:
# 72
